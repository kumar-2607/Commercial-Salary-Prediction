# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Step 1: Import Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2: Load Dataset

# %%
df = pd.read_csv("1-employee_salary_dataset.csv")

# %% [markdown]
# ### Step 3: Display Dataset

# %%
df.head()
# Out:
#   Employee_ID   Age  Gender Education  Experience_Years  Department Job_Level  \
# 0    EMP10001  28.0    Male    Master               6.0  Operations    Junior
# 1    EMP10002  26.0  Female  Bachelor               5.0  Operations    Junior
# 2    EMP10003  31.0  Female  Bachelor               5.0   Marketing    Junior
# 3    EMP10004  59.0  Female  Bachelor              29.0       Sales      Lead
# 4    EMP10005  23.0  Female  Bachelor               0.0       Sales    Junior
#
#    Performance_Rating  Certifications  Overtime_Hours Remote_Work       City  \
# 0                   1               4              15         Yes    Chennai
# 1                   2               3              32          No      Delhi
# 2                   4               5              17         Yes  Hyderabad
# 3                   3               0              46          No     Mumbai
# 4                   2               4               5         Yes  Hyderabad
#
# ...

# %%
df.tail()
# Out:
#      Employee_ID   Age  Gender Education  Experience_Years  Department  \
# 5015    EMP13816  25.0  Female       PhD               4.0  Operations
# 5016    EMP13817  21.0    Male  Bachelor               0.0   Marketing
# 5017    EMP13818  60.0  Female    Master              25.0          IT
# 5018    EMP13819  32.0    Male   Diploma              10.0          HR
# 5019    EMP13820  33.0    Male  Bachelor               3.0   Marketing
#
#      Job_Level  Performance_Rating  Certifications  Overtime_Hours  \
# 5015    Junior                   3               6               1
# 5016    Junior                   1               3              19
# 5017      Lead                   4               8              51
# 5018       Mid                   2               5              12
# 5019    Junior                   1               5              46
#
#      Remote_Work       City  Company_Tenure  Projects_Completed  Skill_Score  \
# ...

# %% [markdown]
# ### Step 4: Shape of Dataset

# %%
df.shape
# Out:
# (5020, 16)

# %% [markdown]
# ### Step 5: Column Names

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Education', 'Experience_Years',
#        'Department', 'Job_Level', 'Performance_Rating', 'Certifications',
#        'Overtime_Hours', 'Remote_Work', 'City', 'Company_Tenure',
#        'Projects_Completed', 'Skill_Score', 'Annual_Salary_LPA'],
#       dtype='object')

# %% [markdown]
# ### Step 6: Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5020 entries, 0 to 5019
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         5020 non-null   object
#  1   Age                 4960 non-null   float64
#  2   Gender              5020 non-null   object
#  3   Education           5020 non-null   object
#  4   Experience_Years    4960 non-null   float64
#  5   Department          5020 non-null   object
#  6   Job_Level           5020 non-null   object
#  7   Performance_Rating  5020 non-null   int64
#  8   Certifications      5020 non-null   int64
#  9   Overtime_Hours      5020 non-null   int64
#  10  Remote_Work         5020 non-null   object
#  11  City                5020 non-null   object
#  12  Company_Tenure      5020 non-null   int64
#  13  Projects_Completed  5020 non-null   int64
#  14  Skill_Score         4960 non-null   float64
# ...

# %% [markdown]
# ### Step 7: Statistical Summary

# %%
df.describe()
# Out:
#                Age  Experience_Years  Performance_Rating  Certifications  \
# count  4960.000000       4960.000000         5020.000000     5020.000000
# mean     40.468145         11.152419            3.034661        4.986255
# std      11.576821          7.724104            1.411955        3.159127
# min      14.000000          0.000000            1.000000        0.000000
# 25%      30.000000          5.000000            2.000000        2.000000
# 50%      41.000000         11.000000            3.000000        5.000000
# 75%      51.000000         17.000000            4.000000        8.000000
# max      90.000000         33.000000            5.000000       10.000000
#
#        Overtime_Hours  Company_Tenure  Projects_Completed  Skill_Score  \
# count     5020.000000     5020.000000         5020.000000  4960.000000
# mean        29.907968        5.500996           15.481076    74.922984
# std         17.710887        4.415711            8.691489    14.814703
# ...

# %% [markdown]
# ### Step 8: Check Data Types

# %%
df.dtypes
# Out:
# Employee_ID            object
# Age                   float64
# Gender                 object
# Education              object
# Experience_Years      float64
# Department             object
# Job_Level              object
# Performance_Rating      int64
# Certifications          int64
# Overtime_Hours          int64
# Remote_Work            object
# City                   object
# Company_Tenure          int64
# Projects_Completed      int64
# Skill_Score           float64
# Annual_Salary_LPA     float64
# dtype: object

# %% [markdown]
# ### Step 9: Check Missing Values

# %%
df.isnull().sum()
# Out:
# Employee_ID            0
# Age                   60
# Gender                 0
# Education              0
# Experience_Years      60
# Department             0
# Job_Level              0
# Performance_Rating     0
# Certifications         0
# Overtime_Hours         0
# Remote_Work            0
# City                   0
# Company_Tenure         0
# Projects_Completed     0
# Skill_Score           60
# Annual_Salary_LPA      0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Employee_ID           0.000000
# Age                   1.195219
# Gender                0.000000
# Education             0.000000
# Experience_Years      1.195219
# Department            0.000000
# Job_Level             0.000000
# Performance_Rating    0.000000
# Certifications        0.000000
# Overtime_Hours        0.000000
# Remote_Work           0.000000
# City                  0.000000
# Company_Tenure        0.000000
# Projects_Completed    0.000000
# Skill_Score           1.195219
# Annual_Salary_LPA     0.000000
# dtype: float64

# %% [markdown]
# ## Step 10: Check Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Age, Gender, Education, Experience_Years, Department, Job_Level, Performance_Rating, Certifications, Overtime_Hours, Remote_Work, City, Company_Tenure, Projects_Completed, Skill_Score, Annual_Salary_LPA]
# Index: []

# %% [markdown]
# ### Step 11: Remove Duplicate Records

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 12: Drop Unnecessary Column

# %%
df.drop("Employee_ID",axis=1,inplace=True)

# %%
df.head()
# Out:
#     Age  Gender Education  Experience_Years  Department Job_Level  \
# 0  28.0    Male    Master               6.0  Operations    Junior
# 1  26.0  Female  Bachelor               5.0  Operations    Junior
# 2  31.0  Female  Bachelor               5.0   Marketing    Junior
# 3  59.0  Female  Bachelor              29.0       Sales      Lead
# 4  23.0  Female  Bachelor               0.0       Sales    Junior
#
#    Performance_Rating  Certifications  Overtime_Hours Remote_Work       City  \
# 0                   1               4              15         Yes    Chennai
# 1                   2               3              32          No      Delhi
# 2                   4               5              17         Yes  Hyderabad
# 3                   3               0              46          No     Mumbai
# 4                   2               4               5         Yes  Hyderabad
#
#    Company_Tenure  Projects_Completed  Skill_Score  Annual_Salary_LPA
# ...

# %% [markdown]
# ### Step 13: Separate Numerical & Categorical Columns

# %% [markdown]
# ##### Numerical Columns

# %%
numerical_cols = df.select_dtypes(include=['int64','float64']).columns

numerical_cols
# Out:
# Index(['Age', 'Experience_Years', 'Performance_Rating', 'Certifications',
#        'Overtime_Hours', 'Company_Tenure', 'Projects_Completed', 'Skill_Score',
#        'Annual_Salary_LPA'],
#       dtype='object')

# %% [markdown]
# ##### Categorial Columns

# %%
categorical_cols = df.select_dtypes(include='object').columns

categorical_cols
# Out:
# Index(['Gender', 'Education', 'Department', 'Job_Level', 'Remote_Work',
#        'City'],
#       dtype='object')

# %% [markdown]
# ### Step 14: Unique Values in Categorical Columns

# %%
for col in categorical_cols:
    print(col)
    print(df[col].unique())
    print("-"*50)
# Out:
# Gender
# ['Male' 'Female']
# --------------------------------------------------
# Education
# ['Master' 'Bachelor' 'Diploma' 'PhD']
# --------------------------------------------------
# Department
# ['Operations' 'Marketing' 'Sales' 'IT' 'HR']
# --------------------------------------------------
# Job_Level
# ['Junior' 'Lead' 'Mid' 'Senior' 'Manager']
# --------------------------------------------------
# Remote_Work
# ['Yes' 'No']
# --------------------------------------------------
# City
# ['Chennai' 'Delhi' 'Hyderabad' 'Mumbai']
# --------------------------------------------------

# %% [markdown]
# ### Step 15: Correct Inconsistent Categories

# %%
df['Gender']=df['Gender'].replace({'male':'Male','FEMALE':'Female'})

# %%
df['Remote_Work']=df['Remote_Work'].replace({'YES':'Yes','no':'No'})

# %%
for col in ['Gender','Remote_Work']:
    print(df[col].unique())
# Out:
# ['Male' 'Female']
# ['Yes' 'No']

# %% [markdown]
# ### Step 16: Check Invalid Numerical Values

# %% [markdown]
# ##### Age

# %%
df[df['Age']<18]
# Out:
#        Age  Gender Education  Experience_Years Department Job_Level  \
# 536   15.0    Male  Bachelor              20.0         IT    Senior
# 1391  16.0    Male  Bachelor               0.0      Sales    Junior
# 1477  14.0  Female   Diploma               3.0  Marketing    Junior
#
#       Performance_Rating  Certifications  Overtime_Hours Remote_Work     City  \
# 536                    2               7              22         Yes   Mumbai
# 1391                   2               9              39         Yes  Chennai
# 1477                   5               6              10         Yes    Delhi
#
#       Company_Tenure  Projects_Completed  Skill_Score  Annual_Salary_LPA
# 536               13                  15         97.0              59.80
# 1391               0                  11         51.0              20.42
# 1477               3                  30         66.0              39.14

# %%
df[df['Age']>70]
# Out:
#        Age  Gender Education  Experience_Years  Department Job_Level  \
# 161   75.0    Male    Master              18.0  Operations    Senior
# 1485  80.0  Female  Bachelor               1.0   Marketing    Junior
# 1647  90.0  Female  Bachelor               8.0       Sales       Mid
#
#       Performance_Rating  Certifications  Overtime_Hours Remote_Work     City  \
# 161                    5               3              46          No   Mumbai
# 1485                   2               6              54         Yes    Delhi
# 1647                   4               0              16         Yes  Chennai
#
#       Company_Tenure  Projects_Completed  Skill_Score  Annual_Salary_LPA
# 161                1                  19         80.0              70.68
# 1485               1                   1         63.0              23.14
# 1647               8                   2         51.0              30.02

# %% [markdown]
# #### Experience_Years

# %%
df[df['Experience_Years']<0]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education, Experience_Years, Department, Job_Level, Performance_Rating, Certifications, Overtime_Hours, Remote_Work, City, Company_Tenure, Projects_Completed, Skill_Score, Annual_Salary_LPA]
# Index: []

# %% [markdown]
# ##### Skill_Score

# %%
df[df['Skill_Score']>100]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education, Experience_Years, Department, Job_Level, Performance_Rating, Certifications, Overtime_Hours, Remote_Work, City, Company_Tenure, Projects_Completed, Skill_Score, Annual_Salary_LPA]
# Index: []

# %% [markdown]
# ##### Performance_Rating

# %%
df[df['Performance_Rating']>5]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education, Experience_Years, Department, Job_Level, Performance_Rating, Certifications, Overtime_Hours, Remote_Work, City, Company_Tenure, Projects_Completed, Skill_Score, Annual_Salary_LPA]
# Index: []

# %% [markdown]
# ### Step 17: Fix Invalid Values
#
# Replace invalid values with NaN.

# %% [markdown]
# ##### Age

# %%
df.loc[(df['Age']<18) | (df['Age']>70),'Age']=np.nan

# %% [markdown]
# ##### Experience

# %%
df.loc[df['Experience_Years']<0,'Experience_Years']=np.nan

# %% [markdown]
# ##### Skill_Score

# %%
df.loc[df['Skill_Score']>100,'Skill_Score']=np.nan

# %% [markdown]
# ##### Performance

# %%
df.loc[(df['Performance_Rating']<1) | (df['Performance_Rating']>5),'Performance_Rating']=np.nan

# %% [markdown]
# ### Step 18: Fill Missing Values

# %%
df.isnull().sum()
# Out:
# Age                   66
# Gender                 0
# Education              0
# Experience_Years      60
# Department             0
# Job_Level              0
# Performance_Rating     0
# Certifications         0
# Overtime_Hours         0
# Remote_Work            0
# City                   0
# Company_Tenure         0
# Projects_Completed     0
# Skill_Score           60
# Annual_Salary_LPA      0
# dtype: int64

# %%
df.fillna({'Age':df['Age'].median()},inplace=True)
df.fillna({'Experience_Years': df['Experience_Years'].median()},inplace=True)
df.fillna({'Skill_Score':df['Skill_Score'].median()},inplace=True)
df.fillna({'Performance_Rating':df['Performance_Rating'].median()},inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Education             0
# Experience_Years      0
# Department            0
# Job_Level             0
# Performance_Rating    0
# Certifications        0
# Overtime_Hours        0
# Remote_Work           0
# City                  0
# Company_Tenure        0
# Projects_Completed    0
# Skill_Score           0
# Annual_Salary_LPA     0
# dtype: int64

# %% [markdown]
# ### Step 19: Check Outliers

# %%
plt.figure(figsize=(15,8))

for i, col in enumerate(numerical_cols, 1):

    plt.subplot(3,4,i)

    sns.boxplot(y=df[col])

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Step 20: Remove Outliers

# %%
def remove_outliers(df,column):

    Q1 = df[column].quantile(0.25)

    Q3 = df[column].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR

    upper = Q3 + 1.5 * IQR

    return df[(df[column]>=lower) & (df[column]<=upper)]

# %%
# Remove outliers only from feature columns
for col in numerical_cols:
    if col != 'Annual_Salary_LPA':
        df = remove_outliers(df, col)

# %%
df['Annual_Salary_LPA'].describe()
# Out:
# count    5020.000000
# mean       46.361203
# std        14.427832
# min        15.530000
# 25%        35.530000
# 50%        45.085000
# 75%        55.560000
# max       184.190000
# Name: Annual_Salary_LPA, dtype: float64

# %% [markdown]
# ### Step 21: Verify Shape

# %%
df.shape
# Out:
# (5020, 15)

# %% [markdown]
# ### Step 22: Correlation Matrix

# %%
plt.figure(figsize=(12,10))

sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')

plt.show()

# %% [markdown]
# ### Step 23: Feature Encoding

# %% [markdown]
# ##### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Gender']=le.fit_transform(df['Gender'])

df['Remote_Work']=le.fit_transform(df['Remote_Work'])

# %%
job_mapping = {'Junior':1,'Mid':2,'Senior':3,'Lead':4,'Manager':5}

df['Job_Level'] = df['Job_Level'].map(job_mapping)

# %% [markdown]
# ##### One Hot Encoding

# %%
# df=pd.get_dummies(df,columns=['Education','Department','City'],drop_first=True,dtype=int)

# %%
df['Education']=df['Education'].map({'Diploma':0, 'Bachelor':1, 'Master':2,'PhD':3})
df['Department']=df['Department'].map({'Operations':0, 'IT':1, 'Finance':2,'Sales':3,'HR':4,'Marketing':5})
df['City']=df['City'].map({'Hyderabad':0, 'Mumbai':1, 'Pune':2,'Chennai':3,'Bangalore':4, 'Delhi':5})

# %% [markdown]
# ### Step 24: Separate Features & Target

# %%
X = df.drop('Annual_Salary_LPA', axis=1)

y = df['Annual_Salary_LPA']

# %% [markdown]
# ### Step 25: Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# ### Step 26: Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %% [markdown]
# ### Step 27: Train Multiple Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

lr = LinearRegression()
rf = RandomForestRegressor()
gbr = GradientBoostingRegressor()
xg = XGBRegressor()

lr.fit(X_train, y_train)
rf.fit(X_train, y_train)
gbr.fit(X_train, y_train)
xg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ### Step 28: Prediction

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = rf.predict(X_test)
y_pred3 = gbr.predict(X_test)
y_pred4 = xg.predict(X_test)

# %% [markdown]
# ### Step 29: Model Evaluation

# %%
from sklearn.metrics import (mean_absolute_error,mean_squared_error,r2_score)
import numpy as np

score1 = r2_score(y_test, y_pred1)
score2 = r2_score(y_test,y_pred2)
score3 = r2_score(y_test,y_pred3)
score4 = r2_score(y_test,y_pred4)

print("R² Score :", score1)
print("R² Score :", score2)
print("R² Score :", score3)
print("R² Score :", score4)
# Out:
# R² Score : 0.7714770413604091
# R² Score : 0.7452276194528407
# R² Score : 0.7784385581765484
# R² Score : 0.7345441765246289

# %% [markdown]
# ### Step 30: Compare Actual vs Predicted Values

# %%
import pandas as pd

comparison = pd.DataFrame({'Actual Salary': y_test.values,'Predicted Salary': y_pred1})

comparison.head(10)
# Out:
#    Actual Salary  Predicted Salary
# 0          81.44         82.152101
# 1          27.42         26.949983
# 2          42.16         43.703389
# 3          40.90         39.868117
# 4          40.18         45.915360
# 5          54.13         50.266932
# 6          48.68         47.234792
# 7          67.89         59.817673
# 8          75.48         68.562439
# 9          55.17         53.382635

# %%
final_data = pd.DataFrame({'Models':['LR','RF','GBR','XG'],
                          "R2_SCORE":[score1,score2,score3,score4]})

# %%
final_data
# Out:
#   Models  R2_SCORE
# 0     LR  0.771477
# 1     RF  0.745228
# 2    GBR  0.778439
# 3     XG  0.734544

# %% [markdown]
# ### Step 31: Predict Salary for a New Employee

# %%
df.head(1)
# Out:
#     Age  Gender  Education  Experience_Years  Department  Job_Level  \
# 0  28.0       1          2               6.0           0          1
#
#    Performance_Rating  Certifications  Overtime_Hours  Remote_Work  City  \
# 0                 1.0               4              15            1     3
#
#    Company_Tenure  Projects_Completed  Skill_Score  Annual_Salary_LPA
# 0               6                   5         97.0              35.24

# %%
new_employee = pd.DataFrame({
    'Age': [28],
    'Gender': [1],
    'Education':[2],
    'Experience_Years': [6],
    'Department': [0],
    'Job_Level': [1],
    'Performance_Rating': [1],
    'Certifications': [4],
    'Overtime_Hours': [15],
    'Remote_Work': [1],
    'City': [3],
    'Company_Tenure': [6],
    'Projects_Completed': [5],
    'Skill_Score': [97]
})

# %%
new_employee_scaled = scaler.transform(new_employee)

# %%
predicted_salary = lr.predict(new_employee_scaled)

print(f"Predicted Salary: {predicted_salary[0]:.2f} LPA")
# Out:
# Predicted Salary: 36.65 LPA

# %%
sns.barplot(x=final_data['Models'],y=final_data['R2_SCORE'])
# Out:
# <Axes: xlabel='Models', ylabel='R2_SCORE'>

# %% [markdown]
# # 14- Save The Model

# %%
xg = XGBRegressor()
xg_final = xg.fit(X,y)

# %%
import joblib

# %%
joblib.dump(xg_final,'car_price_predictor')
# Out:
# ['car_price_predictor']

# %%
joblib.load('car_price_predictor')
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
model = joblib.load('car_price_predictor')

# %% [markdown]
# # 15- Prediction on New Data

# %%
df.head(1)
# Out:
#     Age  Gender  Education  Experience_Years  Department  Job_Level  \
# 0  28.0       1          2               6.0           0          1
#
#    Performance_Rating  Certifications  Overtime_Hours  Remote_Work  City  \
# 0                 1.0               4              15            1     3
#
#    Company_Tenure  Projects_Completed  Skill_Score  Annual_Salary_LPA
# 0               6                   5         97.0              35.24

# %% [markdown]
# # 16 - Save your model in JSON format to deploy on Streamlit

# %%
xg_final.save_model('xgb_model.json')
